# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("cleaned_db.csv")

# %%
df
# Out:
#       work_year           experience_level employment_type       job_title  \
# 0          2023            3. Senior_level       Full_Time          Others
# 1          2023  2. Mid_Intermediate_level     Contractual          Others
# 2          2023  2. Mid_Intermediate_level     Contractual          Others
# 3          2023            3. Senior_level       Full_Time  Data Scientist
# 4          2023            3. Senior_level       Full_Time  Data Scientist
# ...         ...                        ...             ...             ...
# 3725       2020            3. Senior_level       Full_Time  Data Scientist
# 3726       2021  2. Mid_Intermediate_level       Full_Time          Others
# 3727       2020             1. Entry_level       Full_Time  Data Scientist
# 3728       2020             1. Entry_level     Contractual          Others
# 3729       2021            3. Senior_level       Full_Time          Others
#
#        salary salary_currency  salary_in_usd  remote_ratio company_size  \
# 0       80000             EUR        95847.0           100            L
# 1       30000             USD        36000.0           100            S
# 2       25500             USD        31500.0           100            S
# 3      175000             USD       175000.0           100            M
# 4      120000             USD       120000.0           100            M
# ...       ...             ...            ...           ...          ...
# 3725   412000             USD       342000.0           100            L
# 3726   151000             USD       149000.0           100            L
# 3727   105000             USD        92000.0           100            S
# 3728   100000             USD        87000.0           100            L
# 3729  7000000             INR        96665.0            50            L
#
#      country_employee_residence  country_company_location
# 0                         Spain                     Spain
# 1      United States of America  United States of America
# 2      United States of America  United States of America
# 3                        Canada                    Canada
# 4                        Canada                    Canada
# ...                         ...                       ...
# 3725   United States of America  United States of America
# 3726   United States of America  United States of America
# 3727   United States of America  United States of America
# 3728   United States of America  United States of America
# 3729                      India                    Others
#
# [3730 rows x 11 columns]

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3730.000000  3.730000e+03    3730.000000   3730.000000
# mean   2022.383914  1.902261e+05  137027.839142     46.126005
# std       0.679595  6.733753e+05   63085.779226     48.624195
# min    2020.000000  6.000000e+03    3000.000000      0.000000
# 25%    2022.000000  1.000000e+05   93000.000000      0.000000
# 50%    2022.000000  1.381750e+05  134700.000000      0.000000
# 75%    2023.000000  1.800000e+05  176000.000000    100.000000
# max    2023.000000  3.040000e+07  342000.000000    100.000000

# %%
df[df['salary_in_usd']<= 750000].salary_in_usd.hist()
# Out:
# <Axes: >

# %%
df.remote_ratio.hist()
# Out:
# <Axes: >

# %%
# create grouped boxplot 
sns.boxplot(x = df['remote_ratio'],
            y = df['salary_in_usd'])
# Out:
# <Axes: xlabel='remote_ratio', ylabel='salary_in_usd'>

# %%
# create grouped boxplot 
sns.boxplot(y = df['country_company_location'],
            x = df['salary_in_usd'],
            orient = 'h')
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='country_company_location'>

# %%
df.experience_level.value_counts()
# Out:
# 3. Senior_level              2516
# 2. Mid_Intermediate_level     797
# 1. Entry_level                303
# 4. Executive_level            114
# Name: experience_level, dtype: int64

# %%
df.employment_type.value_counts()
# Out:
# Full_Time      3699
# Part_Time        13
# Contractual       9
# Freelancer        9
# Name: employment_type, dtype: int64

# %%
df.job_title.value_counts()[:10].sum()
# Out:
# 3730

# %%
# create grouped boxplot 
sns.boxplot(x = df['company_size'],
            y = df['salary_in_usd'])
# Out:
# <Axes: xlabel='company_size', ylabel='salary_in_usd'>

# %%
# create grouped boxplot 
sns.boxplot(y = df['job_title'],
            x = df['salary_in_usd'],
            orient = 'h')
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='job_title'>

# %%
# create grouped boxplot 
sns.boxplot(y = df['experience_level'],
            x = df['salary_in_usd'],
            orient = 'h')
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='experience_level'>

# %%
df.job_title.value_counts()
# Out:
# Data Engineer                1040
# Others                        871
# Data Scientist                840
# Data Analyst                  612
# Machine Learning Engineer     289
# Analytics Engineer            103
# Name: job_title, dtype: int64

# %%
list(df.experience_level.value_counts().keys())
# Out:
# ['3. Senior_level',
#  '2. Mid_Intermediate_level',
#  '1. Entry_level',
#  '4. Executive_level']
